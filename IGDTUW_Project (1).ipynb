# %%
import cv2
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from google.colab.patches import cv2_imshow

# %%
# !kaggle datasets download -d msambare/fer2013
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#  94% 57.0M/60.3M [00:00<00:00, 104MB/s]
# 100% 60.3M/60.3M [00:00<00:00, 86.6MB/s]

# %%
import zipfile
with zipfile.ZipFile('/content/fer2013.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

# %%
# Define paths to training and testing data
train_dir = '/content/train'
test_dir = '/content/test'

# Data augmentation and rescaling for training data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Rescaling only for test data
test_datagen = ImageDataGenerator(rescale=1./255)

# Load training data
training_set = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical'
)

# Load testing data
test_set = test_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
model = Sequential()

# 1st Convolution Layer
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(48, 48, 1)))
model.add(MaxPooling2D(pool_size=(2,2)))

# 2nd Convolution Layer
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# 3rd Convolution Layer
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten the layers
model.add(Flatten())

# Fully connected layer
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))  # 7 classes for 7 emotions

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(training_set, epochs=25, validation_data=test_set)

# Save the trained model
model.save('/content/emotion_recognition_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 39s 36ms/step - accuracy: 0.2652 - loss: 1.7919 - val_accuracy: 0.4191 - val_loss: 1.5313
# Epoch 2/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 27s 30ms/step - accuracy: 0.3983 - loss: 1.5480 - val_accuracy: 0.4703 - val_loss: 1.3762
# Epoch 3/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.4494 - loss: 1.4380 - val_accuracy: 0.4769 - val_loss: 1.3644
# Epoch 4/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.4673 - loss: 1.3781 - val_accuracy: 0.5075 - val_loss: 1.2805
# Epoch 5/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 27s 30ms/step - accuracy: 0.4907 - loss: 1.3332 - val_accuracy: 0.5279 - val_loss: 1.2230
# Epoch 6/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.5023 - loss: 1.2946 - val_accuracy: 0.5337 - val_loss: 1.2062
# Epoch 7/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 42s 31ms/step - accuracy: 0.5181 - loss: 1.2647 - val_accuracy: 0.5398 - val_loss: 1.2006
# Epoch 8/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 29s 32ms/step - accuracy: 0.5276 - loss: 1.2443 - val_accuracy: 0.5457 - val_loss: 1.1842
# Epoch 9/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.5337 - loss: 1.2298 - val_accuracy: 0.5479 - val_loss: 1.1752
# Epoch 10/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 38s 32ms/step - accuracy: 0.5445 - loss: 1.2025 - val_accuracy: 0.5394 - val_loss: 1.1853
# Epoch 11/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5443 - loss: 1.2057 - val_accuracy: 0.5627 - val_loss: 1.1461
# Epoch 12/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5503 - loss: 1.1907 - val_accuracy: 0.5587 - val_loss: 1.1591
# Epoch 13/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5534 - loss: 1.1720 - val_accuracy: 0.5607 - val_loss: 1.1466
# Epoch 14/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5599 - loss: 1.1642 - val_accuracy: 0.5639 - val_loss: 1.1343
# Epoch 15/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5639 - loss: 1.1565 - val_accuracy: 0.5567 - val_loss: 1.1604
# Epoch 16/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5630 - loss: 1.1542 - val_accuracy: 0.5773 - val_loss: 1.1144
# Epoch 17/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 27s 30ms/step - accuracy: 0.5769 - loss: 1.1331 - val_accuracy: 0.5705 - val_loss: 1.1335
# Epoch 18/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.5717 - loss: 1.1357 - val_accuracy: 0.5830 - val_loss: 1.1208
# Epoch 19/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - accuracy: 0.5731 - loss: 1.1310 - val_accuracy: 0.5821 - val_loss: 1.1153
# Epoch 20/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 39s 31ms/step - accuracy: 0.5815 - loss: 1.1131 - val_accuracy: 0.5756 - val_loss: 1.1306
# Epoch 21/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5802 - loss: 1.1033 - val_accuracy: 0.5779 - val_loss: 1.1163
# Epoch 22/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.5802 - loss: 1.1113 - val_accuracy: 0.5750 - val_loss: 1.1342
# Epoch 23/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 27s 30ms/step - accuracy: 0.5846 - loss: 1.0952 - val_accuracy: 0.5865 - val_loss: 1.1025
# Epoch 24/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.5892 - loss: 1.0940 - val_accuracy: 0.5832 - val_loss: 1.1200
# Epoch 25/25
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.5926 - loss: 1.0801 - val_accuracy: 0.5878 - val_loss: 1.1018
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

video_path = "/content/WIN_20240813_20_27_29_Pro.mp4"

# Load the video file
cap = cv2.VideoCapture(video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create a VideoWriter object to save the output video
out = cv2.VideoWriter('output_video.avi', cv2.VideoWriter_fourcc(*'XVID'), fps, (frame_width, frame_height))

# Load Haar Cascade for face detection
face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        # Extract the face region of interest (ROI)
        roi_gray = gray[y:y+h, x:x+w]
        roi_gray = cv2.resize(roi_gray, (48, 48), interpolation=cv2.INTER_AREA)

        if np.sum([roi_gray]) != 0:
            roi = roi_gray.astype('float') / 255.0
            roi = np.expand_dims(roi, axis=-1)
            roi = np.expand_dims(roi, axis=0)

            # Predict emotion
            prediction = model.predict(roi)[0]
            label = emotion_labels[prediction.argmax()]
            label_position = (x, y)

            # Draw rectangle around the face and label the emotion
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(frame, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Write the processed frame to the output video
    out.write(frame)

    # Optionally display the frame in Colab (can be slow for long videos)
    # cv2_imshow(frame)

# Release the video capture and writer objects
cap.release()
out.release()

# Convert the output video to a format viewable in Colab
import subprocess
subprocess.call(['ffmpeg', '-i', 'output_video.avi', 'output_video.mp4'])

# Display the output video in Colab
from IPython.display import HTML
from base64 import b64encode

mp4 = open('output_video.mp4', 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML("""
<video width=600 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
